# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
hc=pd.read_csv("diabetes prediction.csv")
hc
# Out:
#        gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0      Female  80.0             0              1           never  25.19
# 1      Female  54.0             0              0         No Info  27.32
# 2        Male  28.0             0              0           never  27.32
# 3      Female  36.0             0              0         current  23.45
# 4        Male  76.0             1              1         current  20.14
# ...       ...   ...           ...            ...             ...    ...
# 99995  Female  80.0             0              0         No Info  27.32
# 99996  Female   2.0             0              0         No Info  17.37
# 99997    Male  66.0             0              0          former  27.83
# 99998  Female  24.0             0              0           never  35.42
# 99999  Female  57.0             0              0         current  22.43
#
#        HbA1c_level  blood_glucose_level  diabetes
# 0              6.6                  140         0
# ...

# %%
hc.head()
# Out:
#    gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0  Female  80.0             0              1           never  25.19
# 1  Female  54.0             0              0         No Info  27.32
# 2    Male  28.0             0              0           never  27.32
# 3  Female  36.0             0              0         current  23.45
# 4    Male  76.0             1              1         current  20.14
#
#    HbA1c_level  blood_glucose_level  diabetes
# 0          6.6                  140         0
# 1          6.6                   80         0
# 2          5.7                  158         0
# 3          5.0                  155         0
# 4          4.8                  155         0

# %%
hc.tail()
# Out:
#        gender   age  hypertension  heart_disease smoking_history    bmi  \
# 99995  Female  80.0             0              0         No Info  27.32
# 99996  Female   2.0             0              0         No Info  17.37
# 99997    Male  66.0             0              0          former  27.83
# 99998  Female  24.0             0              0           never  35.42
# 99999  Female  57.0             0              0         current  22.43
#
#        HbA1c_level  blood_glucose_level  diabetes
# 99995          6.2                   90         0
# 99996          6.5                  100         0
# 99997          5.7                  155         0
# 99998          4.0                  100         0
# 99999          6.6                   90         0

# %%
hc.shape
# Out:
# (100000, 9)

# %%
hc.dtypes
# Out:
# gender                  object
# age                    float64
# hypertension             int64
# heart_disease            int64
# smoking_history         object
# bmi                    float64
# HbA1c_level            float64
# blood_glucose_level      int64
# diabetes                 int64
# dtype: object

# %%
hc.describe()
# Out:
#                  age  hypertension  heart_disease            bmi  \
# count  100000.000000  100000.00000  100000.000000  100000.000000
# mean       41.885856       0.07485       0.039420      27.320767
# std        22.516840       0.26315       0.194593       6.636783
# min         0.080000       0.00000       0.000000      10.010000
# 25%        24.000000       0.00000       0.000000      23.630000
# 50%        43.000000       0.00000       0.000000      27.320000
# 75%        60.000000       0.00000       0.000000      29.580000
# max        80.000000       1.00000       1.000000      95.690000
#
#          HbA1c_level  blood_glucose_level       diabetes
# count  100000.000000        100000.000000  100000.000000
# mean        5.527507           138.058060       0.085000
# std         1.070672            40.708136       0.278883
# min         3.500000            80.000000       0.000000
# 25%         4.800000           100.000000       0.000000
# ...

# %%
hc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 9 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   gender               100000 non-null  object
#  1   age                  100000 non-null  float64
#  2   hypertension         100000 non-null  int64
#  3   heart_disease        100000 non-null  int64
#  4   smoking_history      100000 non-null  object
#  5   bmi                  100000 non-null  float64
#  6   HbA1c_level          100000 non-null  float64
#  7   blood_glucose_level  100000 non-null  int64
#  8   diabetes             100000 non-null  int64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 6.9+ MB

# %%
hc.count()
# Out:
# gender                 100000
# age                    100000
# hypertension           100000
# heart_disease          100000
# smoking_history        100000
# bmi                    100000
# HbA1c_level            100000
# blood_glucose_level    100000
# diabetes               100000
# dtype: int64

# %%
hc['gender'].value_counts()
# Out:
# Female    58552
# Male      41430
# Other        18
# Name: gender, dtype: int64

# %%
hc['age'].value_counts()
# Out:
# 80.00    5621
# 51.00    1619
# 47.00    1574
# 48.00    1568
# 53.00    1542
#          ...
# 0.48       83
# 1.00       83
# 0.40       66
# 0.16       59
# 0.08       36
# Name: age, Length: 102, dtype: int64

# %%
hc['bmi'].value_counts()
# Out:
# 27.32    25495
# 23.00      103
# 27.12      101
# 27.80      100
# 24.96      100
#          ...
# 58.23        1
# 48.18        1
# 55.57        1
# 57.07        1
# 60.52        1
# Name: bmi, Length: 4247, dtype: int64

# %%
hc['hypertension'].value_counts()
# Out:
# 0    92515
# 1     7485
# Name: hypertension, dtype: int64

# %%
hc.isnull().sum()
# Out:
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# smoking_history        0
# bmi                    0
# HbA1c_level            0
# blood_glucose_level    0
# diabetes               0
# dtype: int64

# %%
d=hc.duplicated().any()
d
# Out:
# True

# %%
hc=hc.drop_duplicates()
hc
# Out:
#        gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0      Female  80.0             0              1           never  25.19
# 1      Female  54.0             0              0         No Info  27.32
# 2        Male  28.0             0              0           never  27.32
# 3      Female  36.0             0              0         current  23.45
# 4        Male  76.0             1              1         current  20.14
# ...       ...   ...           ...            ...             ...    ...
# 99994  Female  36.0             0              0         No Info  24.60
# 99996  Female   2.0             0              0         No Info  17.37
# 99997    Male  66.0             0              0          former  27.83
# 99998  Female  24.0             0              0           never  35.42
# 99999  Female  57.0             0              0         current  22.43
#
#        HbA1c_level  blood_glucose_level  diabetes
# 0              6.6                  140         0
# ...

# %%
hc.shape
# Out:
# (96146, 9)

# %%
Condition_of_heart = hc['heart_disease'].value_counts()
plt.pie(Condition_of_heart,colors=['blue','red'],labels=["0","1"],autopct='%1.1f%%')
plt.title('Condition of heart')
plt.show()

# %%
print('Unique values\n',hc['smoking_history'].unique())
print('Value Counts\n',hc['smoking_history'].value_counts())
sns.countplot(data=hc,x='smoking_history',hue='diabetes')
# Out:
# Unique values
#  ['never' 'No Info' 'current' 'former' 'ever' 'not current']
# Value Counts
#  never          34398
# No Info        32887
# former          9299
# current         9197
# not current     6367
# ever            3998
# Name: smoking_history, dtype: int64
# <Axes: xlabel='smoking_history', ylabel='count'>

# %%
bgl = hc['blood_glucose_level']
sns.displot(hc['blood_glucose_level'])

# %%
correlation_matrix = hc.corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()
# Out:
# <ipython-input-64-3253907ff930>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = hc.corr()

# %%
age = hc['age']
sns.displot(hc['age'])

# %%
age = hc['age']
plt.title('Boxplot of Age by Diabetes Status')
sns.boxplot(data=hc,x='diabetes',y='age')
# Out:
# <Axes: title={'center': 'Boxplot of Age by Diabetes Status'}, xlabel='diabetes', ylabel='age'>

# %%
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
sns.countplot(x='hypertension', hue='diabetes', data=hc)
plt.title('Countplot of Hypertension by Diabetes')
plt.subplot(1, 2, 2)
sns.countplot(x='heart_disease', hue='diabetes', data=hc)
plt.title('Countplot of Heart Disease by Diabetes')
plt.show()

# %%
fig, axes = plt.subplots(1,2, figsize = (18,4))
sns.boxplot(x = 'blood_glucose_level', ax = axes[0], data = hc)
sns.boxplot(x = 'bmi', ax = axes[1], data = hc)
# Out:
# <Axes: xlabel='bmi'>

# %%
sns.countplot(data=hc,x='smoking_history',hue='diabetes')
# Out:
# <Axes: xlabel='smoking_history', ylabel='count'>

# %%
fig, axes = plt.subplots(3,2, figsize=(15,12),sharey=True)
sns.countplot(x='gender',hue='diabetes',data=hc,ax=axes[0,0])
sns.countplot(x='heart_disease',hue='diabetes',data=hc,ax=axes[0,1])
sns.countplot(x='hypertension',hue='diabetes',data=hc,ax=axes[1,0])
sns.countplot(x='blood_glucose_level',hue='diabetes',data=hc,ax=axes[2,0])
sns.countplot(x=hc['smoking_history'],ax=axes[2,1])
sns.countplot(x=hc['HbA1c_level'],ax=axes[1,1])
# Out:
# <Axes: xlabel='HbA1c_level', ylabel='count'>

# %%
sns.boxplot(data=hc,x='diabetes',y='blood_glucose_level')
# Out:
# <Axes: xlabel='diabetes', ylabel='blood_glucose_level'>

# %%
sns.histplot(x='age', hue='diabetes', data=hc, kde=True)
plt.title('Age Distribution by Diabetes Status')
plt.show()

# %%
plt.scatter(hc["blood_glucose_level"], hc["bmi"])
plt.title("Blood Glucose Level vs BMI")
plt.xlabel("Blood Glucose Level")
plt.ylabel("BMI")
plt.show()
